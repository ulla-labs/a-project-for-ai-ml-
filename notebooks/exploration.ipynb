# %% [markdown]
# # Data Exploration Notebook
# Use this notebook to analyze the dataset before training.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# df = pd.read_csv('../data/raw/sample.csv')
# df.head()
